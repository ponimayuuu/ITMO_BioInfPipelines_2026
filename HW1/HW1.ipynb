# %% [markdown]
# # HW 1 Goncharov Evgenii

# %% [markdown]
# ## Running Nextflow with built-in docker support

# %% [markdown]
# ![image.png](attachment:ec55aebb-9f0d-48b4-9812-54731a7453bb.png)

# %% [markdown]
# ### Results

# %% [markdown]
# ![image.png](attachment:dd3642a2-8d67-4de2-b7f1-2443047d8c8e.png)
#
# We see a generated fastqc and multiqc reports in results folder

# %% [markdown]
# ![image.png](attachment:b6ec6a3f-f5f3-4c6b-be40-8bdbbd96ac55.png)

# %% [markdown]
# ## Running Nextflow with conda

# %% [markdown]
# ![image.png](attachment:266184cf-2d63-46a2-866b-f276322f5865.png)

# %% [markdown]
# ![image.png](attachment:421b2579-c437-4897-a4d2-72cd3c372526.png)

# %% [markdown]
# ### Results

# %% [markdown]
# ![image.png](attachment:2d6ca343-5720-4007-92b9-33d08e4e0f9e.png)
#
# Results are the same

# %% [markdown]
# ![image.png](attachment:b3c43925-90d6-447d-9744-3c56bb932bfb.png)

# %% [markdown]
# ## Running pipeline on my own data

# %% [markdown]
# I've already had some downloaded RNA-seq data (Lymphoblastoid transcriptomes form 1000 Genomes geuvadis dataset)
#
# So let's run our pipeline on it

# %% [markdown]
# - To speed up the process, i've cut the inital .fastq file to 100_000 reads

# %% [markdown]
# ![image.png](attachment:b1737f88-6ec8-44c6-8d6d-1dac71c3eef2.png)

# %% [markdown]
# - Then, the standard pipeline with docker profile was run

# %% [markdown]
# ![image.png](attachment:31763cdd-e9e5-428a-9d16-d672bdc84c48.png)

# %% [markdown]
# ### Results

# %% [markdown]
# ![image.png](attachment:0f184687-4368-4981-a67d-f854412c1748.png)
